# %%
import os; os.chdir('..');
# %pwd
# Out:
# '/home/lucky/discord_scrapper'

# %%
# !ls
# Out:
# DiscordMidjourneyPrompts  keys.py	    research  venv
# __pycache__		  requirements.txt  scripts

# %%
json_files= os.listdir("DiscordMidjourneyPrompts")
json_files[:5]
# Out:
# ['general-08_2022_06_26.json',
#  'general-01_2022_07_16.json',
#  'general-01_2022_07_17.json',
#  'general-05_2022_07_01.json',
#  'general-08_2022_07_06.json']

# %%
json_path= f"DiscordMidjourneyPrompts/{json_files[0]}"
json_path
# Out:
# 'DiscordMidjourneyPrompts/general-08_2022_06_26.json'

# %%
import json

json_data= None
with open(json_path, "r") as f:
    json_data= json.load(f)
    
json_data
# Out:
# {'total_results': 1086,
#  'messages': [[{'id': '990767840145571900',
#     'type': 19,
#     'content': "Progress images have been disabled. Don't worry, the results will still be sent when it completes.",
#     'channel_id': '990677659535159327',
#     'author': {'id': '936929561302675456',
#      'username': 'MidJourney Bot',
#      'avatar': '4a79ea7cd151474ff9f6e08339d69380',
#      'avatar_decoration': None,
#      'discriminator': '9282',
#      'public_flags': 65536,
#      'bot': True},
#     'attachments': [],
#     'embeds': [],
#     'mentions': [],
#     'mention_roles': [],
#     'pinned': False,
#     'mention_everyone': False,
#     'tts': False,
#     'timestamp': '2022-06-26T23:57:40.667000+00:00',
#     'edited_timestamp': '2022-06-26T23:59:05.630000+00:00',
#     'flags': 0,
#     'components': [],
#     'application_id': '936929561302675456',
#     'webhook_id': '936929561302675456',
#     'message_reference': {'channel_id': '990677659535159327',
# ...

# %%
from tqdm import tqdm

# %%
for message in tqdm(json_data['messages']):
    print(message[0]["content"])
# Out:
# 100%|██████████| 930/930 [00:00<00:00, 196657.56it/s]
# Progress images have been disabled. Don't worry, the results will still be sent when it completes.
# **<https://s.mj.run/kqqz1NOpcIc> a female portrait, cyberpunk, electronic implants, circuit boards, transistors, connections, wires of different sizes --video --iw 1** - <@373768908089458699> (relaxed)
# Progress images have been disabled. Don't worry, the results will still be sent when it completes.
# **<https://s.mj.run/CHqu1bUFb-Y> a female portrait, cyberpunk, electronic implants, circuit boards, transistors, connections, wires of different sizes --video --iw 1** - <@373768908089458699> (relaxed)
# Progress images have been disabled. Don't worry, the results will still be sent when it completes.
# **<https://s.mj.run/Dphs_CN9GuI> a female portrait, cyberpunk, electronic implants, circuit boards, transistors, connections, wires of different sizes --video --iw 1** - <@373768908089458699> (relaxed)
# ...
